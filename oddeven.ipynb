# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshi-shr/davis_training/blob/main/oddeven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to check a number is even or odd
def oddeven(num):
    if num%2 == 0:
        print("num is even")
    else:
        print("num is odd")
num = int(input("enter a number"))
oddeven(num)
# Out:
# enter a number7
# num is odd
