# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshi-shr/davis_training/blob/main/Displayingevenbumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

print("Even factors are:")

for i in range(1, num + 1):
    if num % i == 0 and i % 2 == 0:
        print(i)
# Out:
# Enter a number: 76
# Even factors are:
# 2
# 4
# 38
# 76
